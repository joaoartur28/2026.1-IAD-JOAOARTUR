# %%
largura = 17
altura = 12.0

a = largura//2
print(a)
print(type(a))

b = largura/2.0
print(b)
print(type(b))

c = altura/3
print(c)
print(type(c))

d = 1 + 2 * 5
print(d)
print(type(d))
# Out:
# 8
# <class 'int'>
# 8.5
# <class 'float'>
# 4.0
# <class 'float'>
# 11
# <class 'int'>
