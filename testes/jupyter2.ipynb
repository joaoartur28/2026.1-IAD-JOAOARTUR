# %%
# Dicionários

# %%
#dicionário é como uma lista, mas com chaves e valores

# %%
ingparaport = dict()
print(ingparaport)
# Out:
# {}

# %%
ingparaport["one"] = "um"
print(ingparaport)
# Out:
# {'one': 'um'}

# %%
print(ingparaport['one'])
# Out:
# um

# %%
palavra = "brontossauro"
d = dict()
for c in palavra:
    if c not in d:
        d[c] = 1
    else:
        d[c] = d[c] + 1
print(d)
# Out:
# {'b': 1, 'r': 2, 'o': 3, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 1}

# %%
# Dicionários e arquivos 9.2

# %%
fname = input('coloque o nome do arquivo: ')
try:
    fhand = open(fname)
except:
    print('Documento não pode ser aberto', fname)
    exit()

counts = dict()  # 'c' minúsculo
for line in fhand:
    words = line.split()
    for word in words:  # corrigido para 'word'
        if word not in counts:  # 'c' minúsculo
            counts[word] = 1
        else:
            counts[word] = counts[word] + 1

print(counts)
# não está funcionando esse código
