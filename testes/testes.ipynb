# %%
palavra = 'banana'

# %%
type(palavra)
# Out:
# str

# %%
dir(palavra)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print(4)
# Out:
# 4

# %%
type("hello, world!")
# Out:
# str

# %%
print(1,000,000)
# Out:
# 1 0 0

# %%
20 + 20
# Out:
# 40

# %%
40**2
# Out:
# 1600

# %%
40*2
# Out:
# 80

# %%
minuto = 59
minuto//60
# Out:
# 0

# %%
5
x = 5
x + 1
# Out:
# 6

# %%
nome = input("Digite o seu Nome:")
print("Olá",nome+",tudo bem?")
# Out:
# Olá artur,tudo bem?

# %%
Temperatura = float(input("Digite a temperatura em Celsius:"))
CelsiusFahrenheit = (float(Temperatura) * 9/5) + 32
print("A temperatura em Fahrenheit é:", CelsiusFahrenheit)
if Temperatura > 30:
    print("Está quente!")
elif Temperatura < 10:
    print("Está frio!")
elif Temperatura >= 10 and Temperatura <= 30:
    print("Está agradável!")
# Out:
# A temperatura em Fahrenheit é: 86.0
# Está agradável!

# %%
5 == 5
# Out:
# True

# %%
type (True)
# Out:
# bool

# %%
n = 2
n%2 == 0
# Out:
# True

# %%
4%3
# Out:
# 1

# %%
x = int(input("Digite um número inteiro: "))
if x%2 == 0:
    print("x é par")
elif x%2 == 1:
    print("x é ímpar")
# Out:
# x é par

# %%
def fred():
    print("zap")
def jane():
    print("abc")

jane()
fred()
jane()
# Out:
# abc
# zap
# abc

# %%
resposta = ()
while resposta != "sair":
    resposta = input("Digite algo (ou 'sair'): ")
    print("Você digitou:", resposta)
# Out:
# Você digitou: dedeo
# Você digitou: dada
# Você digitou: sair

# %%
try:
    resposta = int(input("Digite um número inteiro: "))
    print("Você digitou:", resposta)
except ValueError:
    print("Isso não é um número inteiro válido.")
# Out:
# Você digitou: 10

# %%
amigos = ['alice', 'José', 'sara']
for amigo in amigos:
    print("Olá", amigo)
# Out:
# Olá alice
# Olá José
# Olá sara

# %%
fruta = "maçã"
letra = fruta[0]
print(letra)
# Out:
# m

# %%
fruta = input("Digite o nome de uma fruta:")

letra = len(fruta) - 1

while letra >= 0:
    print(fruta[letra])
    letra = letra - 1
# Out:
# a
# n
# a
# n
# a
# b

# %%
fruta = input("Digite o nome de uma fruta:")
fruta[:]
# Out:
# 'banana'

# %%
soma_total = 0
quantidade = 0

while True:
    entrada = input("Digite um número: ")
    
    # Condição de parada do loop
    if entrada.lower() == "pronto":
        break
        
    try:
        # Tenta converter a entrada para número decimal (float)
        numero = float(entrada)
        soma_total = soma_total + numero
        quantidade = quantidade + 1
    except ValueError:
        # Se a conversão falhar, captura o erro e avisa o usuário
        print("Entrada Inválida")
        continue

# Exibe os resultados apenas se algum número válido foi digitado
if quantidade > 0:
    media = soma_total / quantidade
    print(f"{soma_total} {quantidade} {media}")
else:
    print("Nenhum número válido foi digitado.")

# %%
nome = input("Digite algo: ")

letra = len(nome) - 1

while letra >= 0:
    print(nome[:5])
    letra = letra -1
# Out:
# banan
# banan
# banan
# banan
# banan
# banan

# %%
palavras = input("Digite algo: ")
contagem = 0
for letra in palavras:
    if letra == "a":
        contagem = contagem + 1
print(contagem)
# Out:
# 5

# %%
horas = float(input("Digite as Horas:"))
taxa = float(input("Digite a taxa:"))

try:
    if horas <= 40:
        pagamento = horas * taxa
    elif horas > 40:
        pagamento = 40 * taxa + (horas - 40) * taxa * 1.5
    print("O pagamento é:", pagamento)
except:
    print("Erro: Por favor, digite valores numéricos válidos.")
# Out:
# O pagamento é: 200.0

# %%
fhand = open('mbox.txt')
count = 0
for line in fhand:
    count = count + 1
print('Line Count:', count)
# Out:
# Line Count: 132044

# %%
fhand = open('mbox.txt')
inp = fhand.read()
print(len(inp))
# Out:
# 6687001

# %%
fhand = open('mbox.txt')
for line in fhand:
    line = line.rstrip()
    if line.find('@uct.ac.za') == -1:
        continue
    print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to stephen.marquard@uct.ac.za using -f
# From: stephen.marquard@uct.ac.za
# Author: stephen.marquard@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# r39753 | david.horwitz@uct.ac.za | 2008-01-04 13:05:51 +0200 (Fri, 04 Jan 2008) | 1 line
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 04:49:08 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# ...
