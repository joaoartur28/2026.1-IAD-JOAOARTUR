# %%
t = 'a', 'b', 'c', 'd', 'e'

# %%
t1 = ('a',)
type(t1)
# A vírgura é importante, pois ela define se é uma tupla ou string
# Out:
# tuple

# %%
t2 = ('a')
type(t1)
# Out:
# str

# %%
t = tuple('lupins')
print(t)
# Out:
# ('l', 'u', 'p', 'i', 'n', 's')

# %%
t = ('a', 'b', 'c', 'd', 'e')
print(t[0])
# Out:
# a

# %%
(0, 1, 2) < (0, 3, 4)
# Out:
# True

# %%
txt = 'but soft what light in yonder window breaks'
words = txt.split()
t = list()
for word in words:
    t.append((len(word), word))
print(t)

t.sort(reverse=True)

res = list()
for length, word in t:
    res.append(word)
print(res)
# Out:
# [(3, 'but'), (4, 'soft'), (4, 'what'), (5, 'light'), (2, 'in'), (6, 'yonder'), (6, 'window'), (6, 'breaks')]
# ['yonder', 'window', 'breaks', 'light', 'what', 'soft', 'but', 'in']
